# %%
import pandas as pd

# %%
data = pd.read_csv('../aircraft_load/data/raw_data.csv', sep=';')

data
# Out:
#            id                creation_time airline_code  flight_number  \
# 0    19882676  2024-05-07T07:57:00.5320000           XY            999
# 1    19882677  2024-05-07T07:57:00.5330000           XY            999
# 2    19882678  2024-05-07T07:57:08.6270000           XY            999
# 3    19882679  2024-05-07T07:57:08.6270000           XY            999
# 4    19883315  2024-05-07T07:58:07.2040000           XY            999
# ..        ...                          ...          ...            ...
# 117  19883568  2024-05-07T08:00:25.4210000           XY            999
# 118  19883569  2024-05-07T08:00:25.4210000           XY            999
# 119  19883570  2024-05-07T08:00:25.4220000           XY            999
# 120  19883571  2024-05-07T08:00:25.4220000           XY            999
# 121  19883572  2024-05-07T08:00:25.4220000           XY            999
#
#      flight_suffix  flight_date departure_airport     user_name  \
# ...

# %%
data.shape
# Out:
# (122, 11)

# %%
data.dtypes
# Out:
# id                     int64
# creation_time         object
# airline_code          object
# flight_number          int64
# flight_suffix        float64
# flight_date            int64
# departure_airport     object
# user_name             object
# action_name           object
# header_line           object
# entry_details         object
# dtype: object
